# %% [markdown]
# ## **Analysis Descriptive for Categoricals Datasets**
#
# For categorical variables, the first step is to determine whether a specific categorical variable has an impact on price. Meaning  we need to assess its significante. to this, we conduct an ANOVA tes to compare the differences between means. After identifying the significant variables, we perform pairwise descriptive analysis for a categories wthi the relevant categorical variable, allowing us to compare their effect on price.
# ANOVA stands for Analysis Of VAriance.
# It is a statistical test used to check whether three or more groups have different means.

# %% [markdown]
# ### **Libraries**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols 
from categorical_function import mean_pairwise, print_mean_prices,anova_categoricals_features

# %%
# %store -r data
data=data

# %store -r categorical_cols
categorical_cols=categorical_cols

# %%
print(data[categorical_cols].columns)
print('*'*90)
#print(data[categorical_cols])

data[categorical_cols].head(10)
# Out:
# Index(['Brand ', 'Model', 'Transmission type', 'Emission group', 'Region',
#        'Engine type', 'next general inspection', 'Color', 'Vehicle model',
#        'Ready to drive', 'Body style', 'Tire type', 'Rim type',
#        'Rights of third parties', 'Transmission type2', 'Accident history'],
#       dtype='object')
# ******************************************************************************************
#     Brand                   Model Transmission type Emission group  \
# 0  Hyundai  Nexo Fuel Cell Sports         automatik             AN
# 1  Renault      Grand Scenic BLUE           manuell             AN
# 2  Hyundai  Nexo Fuel Cell Sports         automatik             AN
# 3     Ford             Ford Focus           manuell             AN
# 4  Renault       Kango rapid Blue           manuell             AN
# 5     Ford             Ford Focus         automatik             AN
# 6  Renault      Grand Scenic BLUE           manuell             AN
# 7  Renault      Grand Scenic BLUE           manuell             AN
# 8  Renault      Grand Scenic BLUE           manuell             AN
# 9  Renault      Grand Scenic BLUE           manuell             AN
#
#          Region Engine type next general inspection  \
# 0  Ketzin/Havel      Diesel              2027-06-01
# 1       Wegberg      Diesel              2027-07-07
# 2         Kamen   Hydrogen               2025-11-01
# 3       Wegberg      Diesel              2025-09-09
# 4      Dortmund      Diesel              2027-02-02
# 5       Wegberg      Diesel              2026-01-01
# 6        unknow      Diesel              2025-09-01
# 7  Ketzin/Havel      Diesel              2025-11-01
# 8       Wegberg      Diesel              2027-02-01
# 9  Ketzin/Havel      Diesel              2025-08-01
#
#                             Color Vehicle model Ready to drive  \
# 0             Argent scintillant            pkw            yes
# 1  Platinum gray 2-layer metallic           pkw            yes
# 2                   platinum gray           SUV            yes
# 3                     Frost White           pkw            yes
# 4     Mineral white 2-layer plain           pkw            yes
# 5           Magnetic grey 2-layer           pkw            yes
# 6          Platinum Gray metallic           pkw         unknow
# 7                   Platinum Gray           pkw            yes
# 8            Arktis white 2-layer           pkw            yes
# 9  Platinum gray 2-layer metallic           pkw            yes
#
#          Body style Tire type      Rim type Rights of third parties  \
# 0    Kombilimousine   summer          steel                      no
# 1       van/Minivan   summer          steel                      no
# 2   Sport Utility     summer       aluminum                      no
# 3             Kombi    winter  light metall                      no
# 4       van/Minivan   summer         unknow                      no
# 5    Kombilimousine   summer    alloy wheel                      no
# 6       van/Minivan   summer          steel                  unknow
# 7       van/Minivan   summer          steel                      no
# 8       transporter    winter         steel                      no
# 9    Kombilimousine    winter         steel                     yes
#
#   Transmission type2 Accident history
# 0  6 Gear mechanical               no
# 1  6 Gear mechanical               no
# 2         mechanical               no
# 3  6 Gear mechanical               no
# 4  5 Gear mechanical               no
# 5   6 Gear automatik               no
# 6  6 Gear mechanical              yes
# 7  6 Gear mechanical               no
# 8  6 Gear mechanical               no
# 9  6 Gear mechanical               no

# %% [markdown]
# ### **Goal of the code**
#
# Your loop performs a statistical test (ANOVA) to check whether each ordinal feature has a significant effect on the variable(Price EUR).
#
# Q() allows variable names with spaces or special characters.
# C() tells the model that this feature is categorical (even if ordinal).
#
# **ANOVA** is used to compare the means of three or more groups to see if at least one group mean is significantly different from the others.
#
# One-way ANOVA: One independent categorical variable.
#
# Two-way ANOVA: Two independent categorical variables

# %% [markdown]
# ##### How to interpret?
#
# - <span style="color:red"><b>p < 0.05 → significant</b></span>
#   → The ordinal feature affects the price
#
# - <span style="color:red"><b>p ≥ 0.05 → not significant</b></span>
#   → The feature does not affect the price

# %% [markdown]
# According the result we can come up that:
#
# <span style="color:green"><b>Body & Paint, Windows & lights,  Headliner & carpets and odor</b></span>  are significant to explain the price of use car, because the p-value is less than 0.0.5 and we reject null hypothesis.
#
# The next step , we want to see for each label in the the categorical variables, which of them has the most impact on price. this,  we make function to caculate  the mean for each label in every single categirical variable.

# %%
for col in categorical_cols:
        mean_pairwise_df = mean_pairwise(col, data,'Sale price')
        print(f'\nMean prices for {col}:\n', mean_pairwise_df)
# Out:
# Mean prices for Brand :
#      Brand     Sale price
# 0     Ford   4780.000000
# 1  Renault   6835.294118
# 2  Hyundai  10420.000000
#
# Mean prices for Model:
#                     Model    Sale price
# 0        transit connect   3200.000000
# 1             Ford Focus   5175.000000
# 2      Grand Scenic BLUE   6827.272727
# 3       Kango rapid Blue   6840.000000
# 4                Traffic   6900.000000
# 5  Nexo Fuel Cell Sports   8750.000000
# 6                 loniq5  17100.000000
#
# Mean prices for Transmission type:
#    Transmission type   Sale price
# 0           manuell  6465.000000
# 1         Automatik  8100.000000
# 2         automatik  9133.333333
#
# Mean prices for Emission group:
#    Emission group   Sale price
# 0             E6  6900.000000
# 1             AN  7126.923077
#
# Mean prices for Region:
#            Region    Sale price
# 0       Freiburg   6000.000000
# 1      Frankfurt   6200.000000
# 2       Dortmund   6750.000000
# 3        Wegberg   6777.777778
# 4   Ketzin/Havel   6871.428571
# 5         unknow   7800.000000
# 6        Herigen   8100.000000
# 7        Leipzig   8200.000000
# 8          Kamen   8600.000000
# 9       Stuttgar   8700.000000
# 10    Thueringen  10000.000000
#
# Mean prices for Engine type:
#    Engine type    Sale price
# 0      Diesel   6452.173913
# 1   Hydrogen    8600.000000
# 2    Hydrogen   9050.000000
# 3  Electronic  17100.000000
#
# Mean prices for next general inspection:
#     next general inspection    Sale price
# 0               2027-03-01   4900.000000
# 1               2026-03-01   4900.000000
# 2               2025-09-09   5000.000000
# 3               2027-02-01   5100.000000
# 4               2025-08-01   5200.000000
# 5               2026-11-11   5400.000000
# 6               2026-01-01   5900.000000
# 7               2027-08-01   6200.000000
# 8               2027-05-22   6400.000000
# 9               2026-10-01   6600.000000
# 10              2026-07-01   6600.000000
# 11              2025-04-01   6900.000000
# 12              2027-02-02   7100.000000
# 13              2025-11-01   7266.666667
# 14              2027-07-07   7350.000000
# 15              2026-02-01   7800.000000
# 16              2025-09-01   7800.000000
# 17              2027-07-01   8200.000000
# 18              2027-06-01   8300.000000
# 19              2026-11-01   8700.000000
# 20              2027-05-01  10000.000000
# 21              2026-09-01  11750.000000
#
# Mean prices for Color:
#                               Color  Sale price
# 0                     Frost white       3200.0
# 1              Blazer blue 2-layer      4900.0
# 2              Forst white 2-layer      4900.0
# 3                      Frost White      5000.0
# 4                   Mineral white       5400.0
# 5            Magnetic grey 2-layer      5900.0
# 6             Arktis white 2-layer      6000.0
# 7             platinum Grayuse car      6400.0
# 8            Mineral white 2-layer      6400.0
# 9                   Mineral white       6600.0
# 10                   Platinum Gray      6600.0
# 11          Platinum Gray metallic      7000.0
# 12     Mineral white 2-layer plain      7100.0
# 13  Platinum gray 2-layer metallic      7150.0
# 14                   Platinum gray      7800.0
# 15               Ocean Indigo  MIC      8100.0
# 16             Argent scintillant       8300.0
# 17                   platinum gray      8600.0
# 18                           white      8700.0
# 19               Titanium gray/MAT     10000.0
# 20                   Galactic gray     17100.0
#
# Mean prices for Vehicle model:
#    Vehicle model  Sale price
# 0           pkw      6350.0
# 1        unknow      8700.0
# 2           SUV     10950.0
#
# Mean prices for Ready to drive:
#    Ready to drive  Sale price
# 0         unknow      6600.0
# 1            yes      7160.0
#
# Mean prices for Body style:
#           Body style  Sale price
# 0       transporter      5450.0
# 1             Kombi      5700.0
# 2               Van      6400.0
# 3       van/Minivan      6600.0
# 4       van/Minivan      6812.5
# 5         Limousine      7800.0
# 6    Kombilimousine      8300.0
# 7   Sport Utility        8600.0
# 8               van      8700.0
#
# Mean prices for Tire type:
#    Tire type   Sale price
# 0    winter  6500.000000
# 1   summer   7295.238095
#
# Mean prices for Rim type:
#         Rim type  Sale price
# 0  light metall      5200.0
# 1   alloy wheel      5400.0
# 2        unknow      7100.0
# 3         steel      7265.0
# 4      aluminum      8600.0
# 5     aluminium     10000.0
#
# Mean prices for Rights of third parties:
#    Rights of third parties   Sale price
# 0                  unknow  7100.000000
# 1                      no  7117.391304
# 2                     yes  7200.000000
#
# Mean prices for Transmission type2:
#    Transmission type2   Sale price
# 0   8 Gear automatik  4900.000000
# 1   6 Gear automatik  5900.000000
# 2  5 Gear mechanical  7066.666667
# 3  6 Gear mechanical  7175.000000
# 4         mechanical  8350.000000
#
# Mean prices for Accident history:
#    Accident history   Sale price
# 0              yes  5866.666667
# 1               no  7272.727273
# 2              no   7300.000000

# %%
#anova_categoricals_features(categorical_cols, data, target="Sale price")

# %%
# ANOVA test
for col in categorical_cols:
    if data[col].nunique() < 2:  # Skip columns with only 1 unique value
        print(f'{col}: skipped (only 1 unique value)')
        continue
    
    formula = f'Q("Sale price") ~ C(Q("{col}"))' #define the formular
    model = ols(formula, data=data).fit() # fit the model
    anova_table = sm.stats.anova_lm(model, typ=2) # ANOVA table
    
    p_value = anova_table["PR(>F)"][0]  # Get p-value
    print(f'{col}: p-value = {p_value:.4f}')
# Out:
# Brand : p-value = 0.0001
# Model: p-value = 0.0000
# Transmission type: p-value = 0.0560
# Emission group: p-value = 0.9302
# Region: p-value = 0.9865
# Engine type: p-value = 0.0000
# next general inspection: p-value = 0.9747
# Color: p-value = 0.0044
# Vehicle model: p-value = 0.0005
# Ready to drive: p-value = 0.7643
# Body style: p-value = 0.7722
# Tire type: p-value = 0.4974
# Rim type: p-value = 0.5911
# Rights of third parties: p-value = 0.9994
# Transmission type2: p-value = 0.8405
# Accident history: p-value = 0.6655

# %% [markdown]
# #### **Zusammenfassung**
# Rim type, Transmission type, Engine type, Region, Brand have the effect under the price

# %%
# %store categorical_cols
# Out:
# Stored 'categorical_cols' (list)
