# %% [markdown]
# ## **Analysis Descriptive for Categoricals Datasets**
#
# For categorical variables, the first step is to determine whether a specific categorical variable has an impact on price. Meaning  we need to assess its significante. to this, we conduct an ANOVA tes to compare the differences between means. After identifying the significant variables, we perform pairwise descriptive analysis for a categories wthi the relevant categorical variable, allowing us to compare their effect on price.
# ANOVA stands for Analysis Of VAriance.
# It is a statistical test used to check whether three or more groups have different means.

# %% [markdown]
# ### **Libraries**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols 
from categorical_function import mean_pairwise, print_mean_prices,anova_categoricals_features

# %%
# %store -r data
data=data

# %store -r categorical_cols
categorical_cols=categorical_cols

# %%
print(data[categorical_cols].columns)
print('*'*90)
#print(data[categorical_cols])

data[categorical_cols].head(10)
# Out:
# Index(['Brand ', 'Model', 'Transmission_type', 'Fueltype', 'nextTUV',
#        'Body_style', 'Tire_type', 'Accident_history', 'images'],
#       dtype='object')
# ******************************************************************************************
#     Brand                   Model Transmission_type    Fueltype     nextTUV  \
# 0  Hyundai  Nexo Fuel Cell Sports         automatik      Diesel  2027-06-01
# 1  Renault      Grand Scenic BLUE           manuell      Diesel  2027-07-07
# 2  Hyundai  Nexo Fuel Cell Sports         automatik   Hydrogen   2025-11-01
# 3     Ford                  Focus           manuell      Diesel  2025-09-09
# 4  Renault       Kango rapid Blue           manuell      Diesel  2027-02-02
# 5     Ford                  Focus         automatik      Diesel  2026-01-01
# 6  Renault      Grand Scenic BLUE           manuell      Diesel  2025-09-01
# 7     Ford                 Fiesta           manuell      Diesel  2027-07-15
# 8  Renault      Grand Scenic BLUE           manuell      Diesel  2025-11-01
# 9  Renault      Grand Scenic BLUE           manuell      Diesel  2027-02-01
#
#          Body_style Tire_type Accident_history images
# 0    Kombilimousine   summer                no    A25
# 1       van/Minivan   summer                no    A17
# 2   Sport Utility     summer                no     A9
# 3             Kombi    winter               no    A16
# 4       van/Minivan   summer                no    A13
# 5    Kombilimousine   summer                no    A33
# 6       van/Minivan   summer               yes    A10
# 7         Limousine   summer                no    A20
# 8       van/Minivan   summer                no     A1
# 9       transporter    winter               no    A32

# %% [markdown]
# ### **Goal of the code**
#
# Your loop performs a statistical test (ANOVA) to check whether each ordinal feature has a significant effect on the variable(Price EUR).
#
# Q() allows variable names with spaces or special characters.
# C() tells the model that this feature is categorical (even if ordinal).
#
# **ANOVA** is used to compare the means of three or more groups to see if at least one group mean is significantly different from the others.
#
# One-way ANOVA: One independent categorical variable.
#
# Two-way ANOVA: Two independent categorical variables

# %% [markdown]
# ##### How to interpret?
#
# - <span style="color:red"><b>p < 0.05 → significant</b></span>
#   → The ordinal feature affects the price
#
# - <span style="color:red"><b>p ≥ 0.05 → not significant</b></span>
#   → The feature does not affect the price

# %% [markdown]
# According the result we can come up that:
#
# <span style="color:green"><b>Body & Paint, Windows & lights,  Headliner & carpets and odor</b></span>  are significant to explain the price of use car, because the p-value is less than 0.0.5 and we reject null hypothesis.
#
# The next step , we want to see for each label in the the categorical variables, which of them has the most impact on price. this,  we make function to caculate  the mean for each label in every single categirical variable.

# %%
for col in categorical_cols:
        mean_pairwise_df = mean_pairwise(col, data,'Sale price')
        print(f'\nMean prices for {col}:\n', mean_pairwise_df)
# Out:
# Mean prices for Brand :
#      Brand     Sale price
# 0     Fiat   3700.000000
# 1     Ford   5100.000000
# 2  Renault   6835.294118
# 3  Hyundai  10420.000000
#
# Mean prices for Model:
#                     Model    Sale price
# 0        transit connect   3200.000000
# 1            Doblo cargo   3700.000000
# 2                  Focus   5175.000000
# 3                 Fiesta   6700.000000
# 4      Grand Scenic BLUE   6827.272727
# 5       Kango rapid Blue   6840.000000
# 6                Traffic   6900.000000
# 7  Nexo Fuel Cell Sports   8750.000000
# 8                 loniq5  17100.000000
#
# Mean prices for Transmission_type:
#    Transmission_type   Sale price
# 0           manuell  6350.000000
# 1         Automatik  8100.000000
# 2         automatik  9133.333333
#
# Mean prices for Fueltype:
#       Fueltype  Sale price
# 0      Diesel      6352.0
# 1   Hydrogen       8600.0
# 2    Hydrogen      9050.0
# 3  Electronic     17100.0
#
# Mean prices for nextTUV:
#         nextTUV    Sale price
# 0   2025-07-07   3700.000000
# 1   2027-03-01   4900.000000
# 2   2026-03-01   4900.000000
# 3   2025-09-09   5000.000000
# 4   2027-02-01   5100.000000
# 5   2025-08-01   5200.000000
# 6   2026-11-11   5400.000000
# 7   2026-01-01   5900.000000
# 8   2027-08-01   6200.000000
# 9   2027-05-22   6400.000000
# 10  2026-10-01   6600.000000
# 11  2026-07-01   6600.000000
# 12  2027-07-15   6700.000000
# 13  2025-04-01   6900.000000
# 14  2027-02-02   7100.000000
# 15  2025-11-01   7266.666667
# 16  2027-07-07   7350.000000
# 17  2026-02-01   7800.000000
# 18  2025-09-01   7800.000000
# 19  2027-07-01   8200.000000
# 20  2027-06-01   8300.000000
# 21  2026-11-01   8700.000000
# 22  2027-05-01  10000.000000
# 23  2026-09-01  11750.000000
#
# Mean prices for Body_style:
#           Body_style  Sale price
# 0       transporter      5100.0
# 1             Kombi      5700.0
# 2               Van      6400.0
# 3       van/Minivan      6600.0
# 4       van/Minivan      6812.5
# 5         Limousine      7250.0
# 6    Kombilimousine      8300.0
# 7   Sport Utility        8600.0
# 8               van      8700.0
#
# Mean prices for Tire_type:
#    Tire_type   Sale price
# 0    winter  6100.000000
# 1   summer   7268.181818
#
# Mean prices for Accident_history:
#    Accident_history   Sale price
# 0              yes  5325.000000
# 1               no  7247.826087
# 2              no   7300.000000
#
# Mean prices for images:
#     images  Sale price
# 0     A29      3200.0
# 1     A37      3700.0
# 2     A24      4900.0
# 3     A34      4900.0
# 4     A16      5000.0
# 5     A32      5100.0
# 6     A15      5400.0
# 7     A33      5900.0
# 8      A4      6200.0
# 9      A8      6400.0
# 10    A22      6400.0
# 11    A35      6600.0
# 12     A1      6600.0
# 13     A2      6600.0
# 14    A19      6600.0
# 15    A17      6600.0
# 16    A20      6700.0
# 17    A21      6900.0
# 18    A13      7100.0
# 19     A6      7200.0
# 20    A23      7800.0
# 21    A10      7800.0
# 22    A11      8100.0
# 23     A3      8200.0
# 24    A25      8300.0
# 25     A9      8600.0
# 26    A12      8700.0
# 27    A31     10000.0
# 28    A28     17100.0

# %%
#anova_categoricals_features(categorical_cols, data, target="Sale price")

# %%
# ANOVA test
for col in categorical_cols:
    if data[col].nunique() < 2:  # Skip columns with only 1 unique value
        print(f'{col}: skipped (only 1 unique value)')
        continue
    
    formula = f'Q("Sale price") ~ C(Q("{col}"))' #define the formular
    model = ols(formula, data=data).fit() # fit the model
    anova_table = sm.stats.anova_lm(model, typ=1) # ANOVA table
    
    p_value = anova_table["PR(>F)"][0]  # Get p-value
    print(f'{col}: p-value = {p_value:.4f}')
# Out:
# Brand : p-value = 0.0002
# Model: p-value = 0.0000
# Transmission_type: p-value = 0.0379
# Fueltype: p-value = 0.0000
# nextTUV: p-value = 0.9739
# Body_style: p-value = 0.6071
# Tire_type: p-value = 0.2824
# Accident_history: p-value = 0.3610
# images: p-value = nan
# c:\Users\dulen\AppData\Local\Programs\Python\Python38\lib\site-packages\statsmodels\stats\anova.py:142: RuntimeWarning: divide by zero encountered in scalar divide
#   (model.ssr / model.df_resid))

# %% [markdown]
# #### **Zusammenfassung**
# Rim type, Transmission type, Engine type, Region, Brand have the effect under the price

# %%
# %store categorical_cols
# Out:
# Stored 'categorical_cols' (list)
